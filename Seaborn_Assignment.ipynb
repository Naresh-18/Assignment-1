# %%
'''Question-1'''

# %%
'''Seaborn is a statistical data visualization library built on top of Matplotlib. 
It provides a high-level interface for drawing attractive and informative statistical graphics. 
Here are five plots that can be created using Seaborn along with their typical use cases:'''

'''Scatter Plot (sns.scatterplot):

Use: Scatter plots are used to visualize the relationship between two continuous variables. 
They are effective for identifying patterns, trends, and clusters in the data'''


import pandas as pd
import seaborn as sns
data = pd.DataFrame({
    'variable1': [1, 2, 3, 4, 5],
    'variable2': [2, 4, 3, 5, 6]
})
sns.scatterplot(x='variable1', y='variable2', data=data)
# Out:
# <Axes: xlabel='variable1', ylabel='variable2'>

# %%
'''Histogram (sns.histplot):

Use: Histograms display the distribution of a single variable by dividing it into bins and counting the number of observations in each bin. 
They are useful for understanding the shape of the data and identifying patterns.'''

import seaborn as sns
data = pd.DataFrame({
    'variable': [1, 2, 3, 4, 5, 3, 4, 5, 6, 7]
})
sns.histplot(data['variable'], kde=True)
# Out:
# <Axes: xlabel='variable', ylabel='Count'>

# %%
'''Box Plot (sns.boxplot):

Use: Box plots (box-and-whisker plots) visualize the distribution of a dataset and help identify potential outliers. 
They are particularly useful for comparing the distribution of a variable across different categories or groups.'''

import seaborn as sns
data = pd.DataFrame({
    'category': ['A', 'A', 'B', 'B', 'C', 'C', 'C', 'D', 'D', 'D'],
    'variable': [1, 2, 3, 4, 5, 3, 4, 5, 6, 7]
})
sns.boxplot(x='category', y='variable', data=data)
# Out:
# <Axes: xlabel='category', ylabel='variable'>

# %%
'''Violin Plot (sns.violinplot):

Use: Violin plots combine aspects of box plots and kernel density estimation. 
They provide insights into the distribution of the data, including its central tendency, spread, and shape. 
Violin plots are effective for visualizing the distribution of a variable across different categories.'''


import seaborn as sns
data = pd.DataFrame({
    'category': ['A', 'A', 'B', 'B', 'C', 'C', 'C', 'D', 'D', 'D'],
    'variable': [1, 2, 3, 4, 5, 3, 4, 5, 6, 7]
})
sns.violinplot(x='category', y='variable', data=data)
# Out:
# <Axes: xlabel='category', ylabel='variable'>

# %%
'''Pair Plot (sns.pairplot):

Use: Pair plots create a matrix of scatter plots for multiple variables in a dataset. 
They are helpful for exploring relationships between multiple variables simultaneously and identifying patterns or correlations.'''

import seaborn as sns
data = pd.DataFrame({
    'variable': [1, 2, 3, 4, 5, 3, 4, 5, 6, 7]
})
sns.pairplot(data)
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
'''Question-2'''

# %%
import seaborn as sns
fmri = sns.load_dataset('fmri')
fmri.head()
# Out:
#   subject  timepoint event    region    signal
# 0     s13         18  stim  parietal -0.017552
# 1      s5         14  stim  parietal -0.080883
# 2     s12         18  stim  parietal -0.081033
# 3     s11         18  stim  parietal -0.046134
# 4     s10         18  stim  parietal -0.037970

# %%
fmri['event'].value_counts()
# Out:
# event
# stim    532
# cue     532
# Name: count, dtype: int64

# %%
fmri['region'].value_counts()
# Out:
# region
# parietal    532
# frontal     532
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(8,4))
sns.lineplot(data=fmri,x='timepoint',y='signal',style='region',hue='event')
plt.title('Signal over Time for Different Events and Regions')
plt.show()

# %%
'''Question-3'''

# %%
import seaborn as sns
titanic = sns.load_dataset('titanic')
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked  class  \
# 0         0       3    male  22.0      1      0   7.2500        S  Third
# 1         1       1  female  38.0      1      0  71.2833        C  First
# 2         1       3  female  26.0      0      0   7.9250        S  Third
# 3         1       1  female  35.0      1      0  53.1000        S  First
# 4         0       3    male  35.0      0      0   8.0500        S  Third
#
#      who  adult_male deck  embark_town alive  alone
# 0    man        True  NaN  Southampton    no  False
# 1  woman       False    C    Cherbourg   yes  False
# 2  woman       False  NaN  Southampton   yes   True
# 3  woman       False    C  Southampton   yes  False
# 4    man        True  NaN  Southampton    no   True

# %%
sns.boxplot(data=titanic,x='pclass',y='age')
# Out:
# <Axes: xlabel='pclass', ylabel='age'>

# %%
sns.boxplot(data=titanic,x='pclass',y='fare')
# Out:
# <Axes: xlabel='pclass', ylabel='fare'>

# %%
'''Question-4'''

# %%
import seaborn as sns
diamonds = sns.load_dataset('diamonds')
diamonds.head()
# Out:
#    carat      cut color clarity  depth  table  price     x     y     z
# 0   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(10,5))
sns.histplot(data=diamonds, x='price',hue='cut',kde=True)
plt.title('Distribution of Price for various diamond cut')
plt.show()

# %%
'''Question-5'''

# %%
import seaborn as sns
iris = sns.load_dataset('iris')
iris.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
sns.pairplot(data=iris,hue='species')
# Out:
# /opt/homebrew/anaconda3/lib/python3.11/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
'''Question-6'''

# %%
import seaborn as sns
flights = sns.load_dataset('flights')
flights.head()
# Out:
#    year month  passengers
# 0  1949   Jan         112
# 1  1949   Feb         118
# 2  1949   Mar         132
# 3  1949   Apr         129
# 4  1949   May         121

# %%
#Pivot the dataset to create a matrix with month on the x-axis, year on the y-axis, and passengers as values
flights_matrix = flights.pivot(index="year", columns="month", values="passengers")
flights_matrix
# Out:
# month  Jan  Feb  Mar  Apr  May  Jun  Jul  Aug  Sep  Oct  Nov  Dec
# year
# 1949   112  118  132  129  121  135  148  148  136  119  104  118
# 1950   115  126  141  135  125  149  170  170  158  133  114  140
# 1951   145  150  178  163  172  178  199  199  184  162  146  166
# 1952   171  180  193  181  183  218  230  242  209  191  172  194
# 1953   196  196  236  235  229  243  264  272  237  211  180  201
# 1954   204  188  235  227  234  264  302  293  259  229  203  229
# 1955   242  233  267  269  270  315  364  347  312  274  237  278
# 1956   284  277  317  313  318  374  413  405  355  306  271  306
# 1957   315  301  356  348  355  422  465  467  404  347  305  336
# 1958   340  318  362  348  363  435  491  505  404  359  310  337
# 1959   360  342  406  396  420  472  548  559  463  407  362  405
# 1960   417  391  419  461  472  535  622  606  508  461  390  432

# %%
import matplotlib.pyplot as plt
sns.heatmap(flights_matrix, 
            cmap="YlGnBu", 
            annot=True, 
            fmt="d", 
            linewidths=.5,
            linecolor="black")
plt.title("Passengers per Month")
plt.show()
